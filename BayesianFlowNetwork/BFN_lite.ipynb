# %%
import torch
from torch import tensor
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![Screenshot%202023-08-22%20at%204.42.33%20PM.png](attachment:Screenshot%202023-08-22%20at%204.42.33%20PM.png)

# %% [markdown]
# Let's create some structured data:

# %%
dim = 10
Data = tensor([[i for i in range(j, j+dim)] for j in range(dim)])
Data_class = tensor([1, 0, 0]) # create 3 dummy classes
# Data = Data/Data.max()
plt.imshow(Data);

# %%
class Alice():
    def __init__(self, noise:tensor):
        self.nosie = noise

    def __call__(self, Data:tensor):
        assert noise.shape == Data.shape, "Data shape needs to be same as noise shape"
        return Data + noise

# %%
class BFN():
    def __init__(self, noise_type:str, data_shape:tuple):
        noise_types = ['gaussian', 'uniforn']
        assert noise_type in noise_types, f"'noise_type' needs to be one of: {noise_types}"
        seld.alice = Alice()
        
    @classmethod
    def __guasian_noise(size:tuple, loc:float=0.0, scale:float=1.0):
        return tensor(np.random.normal(loc=loc, scale=scale, size=size))

# %%
a = Data + tensor(np.random.normal(loc=0.0, scale=1.0, size=Data.size()))
plt.imshow(a);
